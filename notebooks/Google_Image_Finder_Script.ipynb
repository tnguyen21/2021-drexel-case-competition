# %%
! pip install pip --upgrade --user
! pip install Google-Images-Search
! pip install windows-curses
! pip install six --upgrade --user
# Out:
# '-m' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: Google-Images-Search in c:\users\allen\appdata\roaming\python\python37\site-packages (1.3.4)
# Requirement already satisfied: google-api-python-client~=1.7 in c:\users\allen\appdata\roaming\python\python37\site-packages (from Google-Images-Search) (1.12.8)
# Requirement already satisfied: colorama~=0.4 in c:\programdata\anaconda3\lib\site-packages (from Google-Images-Search) (0.4.1)
# Requirement already satisfied: click~=7.0 in c:\programdata\anaconda3\lib\site-packages (from Google-Images-Search) (7.0)
# Requirement already satisfied: six~=1.12 in c:\users\allen\appdata\roaming\python\python37\site-packages (from Google-Images-Search) (1.15.0)
# Requirement already satisfied: Pillow~=7.1.0 in c:\users\allen\appdata\roaming\python\python37\site-packages (from Google-Images-Search) (7.1.2)
# Requirement already satisfied: pyfiglet~=0.8 in c:\users\allen\appdata\roaming\python\python37\site-packages (from Google-Images-Search) (0.8.post1)
# Requirement already satisfied: requests~=2.21 in c:\programdata\anaconda3\lib\site-packages (from Google-Images-Search) (2.22.0)
# Requirement already satisfied: termcolor~=1.1 in c:\users\allen\appdata\roaming\python\python37\site-packages (from Google-Images-Search) (1.1.0)
# Requirement already satisfied: python-resize-image~=1.1 in c:\users\allen\appdata\roaming\python\python37\site-packages (from Google-Images-Search) (1.1.19)
# Requirement already satisfied: google-auth>=1.16.0 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-api-python-client~=1.7->Google-Images-Search) (1.24.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-api-python-client~=1.7->Google-Images-Search) (0.18.1)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-api-python-client~=1.7->Google-Images-Search) (3.0.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-api-python-client~=1.7->Google-Images-Search) (0.0.4)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-api-python-client~=1.7->Google-Images-Search) (1.25.0)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client~=1.7->Google-Images-Search) (2019.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client~=1.7->Google-Images-Search) (1.52.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client~=1.7->Google-Images-Search) (3.14.0)
# Requirement already satisfied: setuptools>=40.3.0 in c:\programdata\anaconda3\lib\site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client~=1.7->Google-Images-Search) (41.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-auth>=1.16.0->google-api-python-client~=1.7->Google-Images-Search) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-auth>=1.16.0->google-api-python-client~=1.7->Google-Images-Search) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\allen\appdata\roaming\python\python37\site-packages (from google-auth>=1.16.0->google-api-python-client~=1.7->Google-Images-Search) (4.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\allen\appdata\roaming\python\python37\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.16.0->google-api-python-client~=1.7->Google-Images-Search) (0.4.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.21->Google-Images-Search) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.21->Google-Images-Search) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.21->Google-Images-Search) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests~=2.21->Google-Images-Search) (2019.9.11)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: windows-curses in c:\programdata\anaconda3\lib\site-packages (2.2.0)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: six in c:\users\allen\appdata\roaming\python\python37\site-packages (1.15.0)
# Collecting six
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
#   Using cached six-1.14.0-py2.py3-none-any.whl (10 kB)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.

# %%
import pandas as pd
from google_images_search import GoogleImagesSearch

# %%
menu_data_no_dupes = pd.read_csv('urban_menu_data_duplicates_removed.csv')

item_names = menu_data_no_dupes['item_name'].tolist()

# %%
item_names
# Out:
# ["overnight apples 'n' oats",
#  'banana bread',
#  'carrot raisin mini muffin',
#  'cherry cobbler bread',
#  'powdered sugar donut',
#  'grits',
#  'old fashioned oatmeal',
#  'biscuits & sausage gravy',
#  'bacon, egg & cheese muffin',
#  'breakfast burrito',
#  'scrambled eggs',
#  'almond milk french toast',
#  'hash brown potato patty',
#  "o'brien potatoes",
#  'turkey sausage patty',
#  'apple cinnamon mini muffin',
#  'southern biscuit',
#  'sunrise tex-mex taco',
#  'crispy tater tots',
#  'bacon',
#  'chocolate chip scone',
#  'whole grain lemon poppy mini muffin',
#  'ham, egg & cheese bagel',
#  'lyonnaise potatoes',
#  'pork sausage patty',
#  'blueberry whole grain mini muffin',
#  'iced cinnamon roll',
#  'broccoli & cheddar strata',
#  'pork sausage links',
#  'belgian waffle',
#  'signature chips',
#  'spicy feta with cauliflower toast',
#  'chicken tenders and fries',
#  'gardenburger black bean burger',
#  'hamburger',
#  'grilled herb chicken sandwich',
#  'philly cheesesteak',
#  'crispy shoestring french fries',
#  'eggplant parmesan melt',
#  'pork, salami and swiss melt',
#  'chicken, bacon & ranch panini',
#  'grilled cheese sandwich',
#  'chipotle chicken quesadilla',
#  'broccoli cheddar soup',
#  'chicken noodle soup',
#  'cilantro-lime barley',
#  'turmeric & quinoa basmati rice',
#  'blanched cauliflower',
#  'blanched fresh kale',
#  'mediterranean saute with orzo',
#  'vegetarian chorizo bowl',
#  'grilled veg & hummus pita',
#  'strawberry chia toast',
#  'vegan kale caesar salad',
#  'veggie antioxidant salad',
#  'marinated green beans & tomato',
#  'rice noodles',
#  'spicy vegetable gumbo',
#  'korean vegetable broth',
#  'dijon fall salad',
#  'garlic herb breadstick',
#  'pesto cavatappi & vegetables',
#  'classic cheese pizza',
#  'mushroom & sausage pizza',
#  'pepperoni pizza',
#  'italian pork & spinach hoagie',
#  'bistro beet burger',
#  'penne pasta salad',
#  'chicken & penne cacciatore',
#  'ranch crusted chicken drumstick',
#  'buffalo chicken melt',
#  'peanut butter power sandwich',
#  'honey dijon chicken snacker',
#  'southwest sweet potato',
#  'sesame noodle salad',
#  'pan-seared ancho lime cod',
#  'bbq chicken pizza',
#  'white pizza',
#  'mediterranean lentil salad',
#  'grilled chicken bruschetta',
#  'black bean stuffed pepper',
#  'spicy sweet potato salad',
#  'asian chicken flatbread',
#  'chicken-bacon ranch flatbread',
#  "devil's food cupcake",
#  'gingerbread thimble cake',
#  'peanut butter cookie',
#  "shrimp po' boy",
#  'chicken cheesesteak',
#  'crispy chicken nuggets',
#  'ham & swiss panini',
#  'melt, chicken, bacon, swiss, chipotle honey, flatbread, wg',
#  'pork carnitas quesadilla',
#  'cranberry-pecan mixed grains',
#  'five spice veggie quinoa bowl',
#  'banana berry nutella(r) toast',
#  'broccoli soup',
#  'cheeseburger mac & cheese bowl',
#  'bacon-cauliflower flatbread',
#  'pepperoni melt',
#  'red velvet cupcake',
#  'sugar cookie',
#  'cherry cheesecake tart',
#  'maple chipotle blt',
#  'nachos con queso',
#  'grilled vegetable quesadilla',
#  'tortellini alfredo',
#  'buffalo cauliflower pizza',
#  'molten chocolate cake',
#  'chocolate chip cookie',
#  'strawberry shortcake parfait',
#  'chicken & hummus ciabatta',
#  'avocado ranch crispy chicken sandwich',
#  'penne',
#  'eggplant parmesan',
#  'hearty grain & tomato salad',
#  'boom boom chicken flatbread',
#  'three cheese bruschetta flatbread',
#  "crunchy s'mores bar",
#  'oatmeal raisin cookie',
#  'roast pork panini',
#  'korean bbq tofu',
#  'seasoned rice',
#  'chicken tikka masala burrito',
#  'grilled vegetable stromboli',
#  'stromboli quattro formaggi',
#  'dulce de leche brownie',
#  'spiced chocolate cupcake',
#  'california turkey bacon wrap',
#  'crispy pork sandwich',
#  'couscous',
#  'vegetable balti',
#  'cheesy shrimp alfredo',
#  'kielbasa mac & cheese',
#  'loaded potato pizza',
#  'cheerios (r) cereal',
#  'bananas foster mini muffin',
#  'cinnamon streusel coffee cake',
#  'powdered sugar donut bites',
#  'egg & cheese muffin',
#  'cheddar & onion frittata',
#  'hash brown potatoes',
#  'turkey sausage link',
#  'apple cinnamon scone',
#  'double chocolate chip mini muffin',
#  'pumpkin pie donut bites',
#  'three cheese & ham strata',
#  'home fries',
#  'cranberry-peach mini muffin',
#  'cinnamon-sugar donut',
#  'donut bites',
#  'whole grain blueberry mini muffin',
#  'moist apple crumb cake',
#  'chocolate donut bites',
#  'pumpkin & cheese mini muffin',
#  'breakfast stromboli with sausage',
#  'middle eastern chickpea toast',
#  'mozzarella sticks',
#  'fish and chips',
#  'ham & swiss melt',
#  "italian meat lover's panini",
#  'chipotle chicken tortilla soup',
#  'minestrone soup',
#  'sriracha-slaw black bean burger',
#  'smashed avocado toast',
#  'pickled cucumber & mint salad',
#  'buffalo chicken mac & cheese',
#  'garlic shrimp flatbread',
#  'mushroom & onion pizza',
#  'italian wrap',
#  'portobello mushroom taco with corn',
#  'arugula chickpea salad',
#  'rigatoni with anise herbed pulled pork',
#  'shakshuka pizza',
#  'grilled vegetable pizza',
#  'grilled chicken caesar wrap',
#  'buffalo-style chicken wings',
#  'sweet potato & poblano salad',
#  'chicken parmesan stromboli',
#  'philly cheesesteak stromboli',
#  'pimento cheese & bacon toast',
#  'curried chickpeas',
#  'old-fashioned coleslaw',
#  'buffalo chicken pizza',
#  'kale pesto turkey ciabatta',
#  'crispy pollock sandwich',
#  'buffalo blue chicken panini',
#  'kung pao cauliflower',
#  'creamy vegan potato salad',
#  'super veggie whole grain flatbread',
#  'mediterranean white bean salad',
#  'mexican black bean salad',
#  'chocolate chip blondie',
#  'pumpkin whoopie pie',
#  'seasoned roast beef',
#  'chicken guacamole wrap',
#  'turkey burger on white roll',
#  'hot dog on roll',
#  'roast beef and swiss melt',
#  'salami & provolone panini',
#  'vegan mac & cheese',
#  'roasted cauliflower & pimento cheese toast',
#  'middle eastern falafel pita',
#  'fritos(r) taco pita',
#  'chicken enchilada',
#  "meat lover's flatbread",
#  'chocolate brownie',
#  'chicken-avocado salad wrap',
#  'chimichurri roasted carrots',
#  'bacon bbq mac & cheese bowl',
#  'bbq chicken stromboli',
#  'philadelphia roast pork stromboli',
#  'chicken & veggie pita',
#  'shrimp & grits',
#  'chicken fajita pizza',
#  'taco pizza',
#  'tandoori chicken wrap',
#  'cheesy bacon cavatappi',
#  'chipotle bbq pork flatbread',
#  'margherita pizza',
#  'pesto grilled vegetable wrap',
#  'chickpea panchmael',
#  'tortellini with meatballs',
#  'meatball stromboli',
#  'mediterranean vegetable wrap',
#  'cauliflower fried rice',
#  'sauteed bruschetta ravioli',
#  'roast pork banh mi',
#  'greek meatball melt',
#  'vegan chili con carne bowl',
#  'chicken poblano flatbread',
#  'spinach & ricotta pizza',
#  'bacon, egg & cheese bagel',
#  'breakfast taco',
#  'vanilla iced donut with sprinkles',
#  'sausage, egg & cheese muffin',
#  'tex-mex migas',
#  'cinnamon donut bites',
#  'bacon, cheddar & egg stromboli',
#  'vanilla iced carrot cake',
#  'chipotle pork & avocado wrap',
#  'vegetarian tomato basil soup',
#  'vegan thai curry',
#  'apple pecan salad',
#  'thai peanut noodle salad',
#  'miso soup broth',
#  'ham & feta pizza',
#  'apple betty',
#  'turkey, apple & honey mustard bagel',
#  'sweet potato fries',
#  'tunisian carrot & walnut salad',
#  'pea & mushroom tortellini alfredo',
#  'cream cheese marbled brownie',
#  'vegan chipotle chicken taco',
#  'garlic potato salad',
#  'tortellini rose',
#  "meat lover's pizza",
#  'chocolate chip crumb cupcake',
#  'old-fashioned bread pudding',
#  'ranch potato chips',
#  'rice noodle & vegetable stir-fry',
#  'caesar pasta salad',
#  'penne & sausage',
#  'chicken cordon blue stromboli',
#  'wicked chocolate thimble cake',
#  'chicken salad club',
#  'twister fries',
#  'fish sticks',
#  'vegan nachos',
#  'garbanzo bean salad',
#  'penne with chicken & kale',
#  'chicken parmesan pizza',
#  'cucumber & onion salad',
#  'sweet apple coleslaw',
#  'crispy cereal bar',
#  'double fudge brownie',
#  'thai chicken lettuce wraps',
#  'chickpea tagine with couscous',
#  'arrabiata cheese ravioli',
#  'cuban stromboli',
#  'chilled veggie ciabatta sandwich',
#  'loaded southern style tots',
#  'cavatappi with spaghetti sauce and zucchini',
#  'onion, jalapeno & sausage pizza',
#  'roasted vegetable wrap',
#  'turkey burrito',
#  'mushroom vegetable casserole',
#  'toasted barley',
#  'butternut squash lasagna',
#  'portobello & pesto baguette',
#  'cheddar grilled chicken sandwich',
#  'vegan baked penne casserole',
#  'baked macaroni & cheese',
#  'caramel apple cheesecake flatbread',
#  'chicken cranberry wrap',
#  'fruited bulgur salad',
#  'bbq beef and cheddar melt',
#  'crunchy onion rings',
#  'monte cristo sandwich',
#  'buffalo cauliflower wings',
#  'hawaiian pizza',
#  'grilled vegetable & hummus wrap',
#  'tangy cucumber salad',
#  'grilled thai chicken wrap',
#  'roasted vegetable taco',
#  'bacon, egg & cheese biscuit sandwich',
#  'sausage, egg & cheese croissant',
#  'egg, ham & cheese burrito',
#  'ham & cheese stuffed potato',
#  'ultimate fudge brownie',
#  'nashville-style hot chicken sandwich',
#  'italian chicken melt',
#  'tomato & bacon grilled cheese',
#  'grilled veggie quesadilla',
#  'three bean chili',
#  'veggie burrito',
#  'green goddess bowl',
#  'cucumber tomato salad',
#  'vegetarian minestrone soup',
#  'turkey muffaletta',
#  'salt & pepper potato chips',
#  'vegan kung pao chicken & kale',
#  'toasted barley salad',
#  'spicy jerk chicken & cavatappi',
#  'chicken & roasted pear wrap',
#  'fresh-cut french fries',
#  'crispy chicken pepper jack slider',
#  'zucchini bolognese',
#  'pickled daikon',
#  'pretzel-crusted cod',
#  'ciabatta, roasted turkey salad, cranberry spread, wg, half',
#  'asian teriyaki noodles',
#  'red potato salad',
#  'cheesy corn casserole',
#  'vegan chicken paella',
#  'tomato chickpea salad',
#  'buffalo chicken stromboli',
#  'italian lentil salad',
#  'tabbouleh',
#  'potato & kale enchiladas',
#  'vegan chicken & kale penne',
#  'peanut butter power toast',
#  'italian roast beef sandwich',
#  'chili lime black bean tostada',
#  'spicy hummus ciabatta',
#  'harvest saute with bulgur',
#  'buffalo chicken wrap',
#  'old bay (r) potato chips',
#  'italian roast pork wrap',
#  'meatball pizza',
#  'mexican street corn wrap',
#  'loaded philly tots',
#  'spinach lentil fritters',
#  'chicken & broccoli ravioli',
#  'turkey reuben stromboli',
#  'grilled veggie & feta ciabatta',
#  'fresh cut french fries',
#  'beef poutine',
#  'vegan frito pie',
#  'pepperoni stromboli',
#  'honey dijon chicken wrap',
#  'crispy chicken & cheese snacker',
#  'vegan cavatappi alfredo',
#  "blueberries 'n' oats",
#  'beef & pickled onion-topped hummus',
#  'mucho nachos',
#  'toasted bulgur wheat',
#  "meat lover's stromboli",
#  'mushroom pizza',
#  'grilled naan',
#  'garlic toast',
#  'macaroni & cheese',
#  'spicy kale & bacon',
#  'sausage pizza',
#  'cauliflower au gratin',
#  'kale with caramelized onions',
#  'caesar salad',
#  'southwest chicken taco',
#  'primavera pizza',
#  'cocoa puff cupcakes',
#  'general tso chicken drumstick',
#  'pepperoni & sausage pizza',
#  'vegetable fried rice',
#  'cavatappi alfredo',
#  'chicken-blue power salad',
#  'tossed salad',
#  'cavatappi alfredo with broccoli',
#  'bulgur-quinoa bliss bowl',
#  'veggie & cheese quiche-adilla',
#  'shrimp & broccoli stir-fry',
#  'philly cheesesteak wrap',
#  'kung pao pork',
#  'grilled chicken parmesan sandwich',
#  'bow ties with sun-dried tomatoes',
#  "chocolate chip devil's food cake",
#  'cranberry-pear cobbler',
#  'beef pho',
#  'buffalo cobb salad',
#  "reese's® brownie",
#  'red velvet thimble cake',
#  'sesame noodles',
#  'chocolate chip cupcake',
#  'raspberry jell-o (r) parfait',
#  'sausage, broccoli & cheddar breakfast scramble',
#  'chocolate chip cookie brownie',
#  'mini chocolate sriracha cake',
#  'vietnamese pork noodle salad',
#  'vanilla cupcake',
#  'confetti brown rice',
#  'shrimp teriyaki',
#  'sweet potato mini muffin',
#  'apple-topped cinnamon roll',
#  'banana-nut mini muffin',
#  'spiced pumpkin scone',
#  'sausage & egg pizza',
#  'caramel pecan brownie',
#  'chicken blt sandwich',
#  'new england clam chowder',
#  'latin beef stew',
#  'italian vegetable blend',
#  'harissa spiced farro',
#  'seven grain blend with wild rice',
#  'basmati rice',
#  'barley & mushroom soup',
#  'harissa chicken quesadilla',
#  'egg noodles',
#  'chicken with marsala sauce',
#  'green beans & almonds',
#  'chicken teriyaki',
#  'shrimp etouffee',
#  'cajun rice',
#  'crispy okra',
#  'watermelon tomato salad',
#  'caprese salad',
#  'mexican baked fish',
#  'papas rancheras',
#  'grilled eggplant',
#  'linguine with lemon-garlic shrimp',
#  'pita wedges',
#  'sweet & sour meatballs',
#  'quinoa fried rice',
#  'garlic broccoli',
#  'fueled-up chicken & sweet potato salad',
#  'garlic flatbread',
#  'home-style patty melt',
#  'apple almond coleslaw',
#  'cajun chicken melt',
#  'grilled cheese with bacon',
#  'grilled vegetable panini',
#  'low sodium vegetable broth',
#  'california blend vegetables',
#  'banana chip cupcake',
#  'creamy cheese polenta',
#  'hearty lasagna',
#  'seasoned peas and carrots',
#  'applesauce cake',
#  'vanilla pudding & oreo(r) cookies',
#  'mashed potatoes & buffalo nuggets',
#  'brownie cupcake',
#  'carrot cake whoopie pie',
#  'jalapeno slaw',
#  'rocky road brownie',
#  "glazed devil's food cake",
#  'chicken & quinoa-topped hummus',
#  'seared vegan caesar wedge salad',
#  "peanut butter devil's food cupcake",
#  'banana pudding parfait',
#  'cheese tortellini marinara',
#  'seasoned spinach',
#  'apple crumb cupcake',
#  'chorizo breakfast burrito',
#  'oreo(r) thimble cake',
#  'chicken with piccata sauce',
#  'confetti rice',
#  'brown rice',
#  'taco salad',
#  'peanut butter pretzel cereal bar',
#  'oreo (r) cookie crumb cupcake',
#  'mexi-rice',
#  'southwest green beans',
#  'mole chicken drumstick',
#  'sofrito black beans & rice',
#  'roasted beets',
#  'lemon-ginger basmati rice',
#  'buffalo mac & cheese bowl',
#  'chocolate pudding parfait',
#  'sugar snap & garden peas',
#  'grilled japanese bbq pork chop',
#  'vegetable fried brown rice',
#  'grilled vegetables',
#  'szechuan chicken noodle bowl',
#  'sriracha chocolate pb mini cupcake',
#  'orange jell-o (r) parfait',
#  'chipotle chicken ciabatta',
#  'old-fashioned mashed potatoes',
#  'yellow summer squash',
#  'chicken tagine',
#  'moroccan roasted carrots',
#  'black beans & rice with bacon',
#  'peanut butter swirl brownie',
#  'blueberry crumb cupcake',
#  'steamed broccoli florets',
#  'shrimp fra diavolo',
#  'buttery penne',
#  'italian green beans',
#  'chicken pho',
#  'broccoli cheddar melt',
#  'nacho grilled cheese',
#  'balsamic chicken & farro bowl',
#  'maple apple cobbler',
#  'southwest fajitas',
#  'spiced pumpkin blondie',
#  "peanut butter devil's food parfait",
#  'vegan beef burrito',
#  'loaded fish tacos',
#  'overstuffed potato',
#  'salted caramel mini cupcake',
#  'hummus vegetable wrap',
#  'chicken, edamame & quinoa salad',
#  'vegan shepherd\x92s pie',
#  'blueberry mini muffin',
#  'sauteed mushroom ravioli']

# %%
# you can provide API key and CX using arguments,
# or you can set environment variables: GCS_DEVELOPER_KEY, GCS_CX

api_key = 'AIzaSyDruwecqgBsd0T9DjUWnQeR88WwrM3d9cI'
project_cx = 'd4d8d063ff32c6dc7'

gis = GoogleImagesSearch(api_key, project_cx)

for dish in item_names: 
    # define search params:    
    _search_params = {
        'q': dish,
        'num': 1,
        'safe': 'high',
        'fileType': 'jpg',
        'imgType': 'photo',
        'imgSize': 'MEDIUM',
        'rights': 'cc_publicdomain'
    }

    # this will search and download:
    gis.search(search_params=_search_params, path_to_dir=r'C:\Users\allen\2021-drexel-case-competition\images')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-17-7283a8e1b3c4> in <module>
#      20
#      21     # this will search and download:
# ---> 22     gis.search(search_params=_search_params, path_to_dir=r'C:\Users\allen\2021-drexel-case-competition\images')
#
# ~\AppData\Roaming\Python\Python37\site-packages\google_images_search\fetch_resize_save.py in search(self, search_params, path_to_dir, width, height, custom_image_name, cache_discovery)
#     119             self._search_params['num'] = num
#     120
# --> 121             self._search_images(*self._get_data())
#     122
#     123             if len(self._search_result) >= self._number_of_images or self.zero_return:
#
# ~\AppData\Roaming\Python\Python37\site-packages\google_images_search\fetch_resize_save.py in _search_images(self, search_params, path_to_dir, width, height, cache_discovery)
#     145         threads = []
#     146         for url in self._google_custom_search.search(
# --> 147             search_params, cache_discovery
#     148         ):
#     149             # initialise image object
#
# ~\AppData\Roaming\Python\Python37\site-packages\google_images_search\google_api.py in search(self, params, cache_discovery)
#      76
#      77         search_params = self._search_params(params)
# ---> 78         res = self._query_google_api(search_params, cache_discovery)
#      79
#      80         results = res.get('items', [])
#
# ~\AppData\Roaming\Python\Python37\site-packages\google_images_search\google_api.py in _query_google_api(self, search_params, cache_discovery)
#      45
#      46         return self._google_build.cse().list(
# ---> 47             cx=self._custom_search_cx, **search_params).execute()
#      48
#      49     def _search_params(self, params):
#
# ~\AppData\Roaming\Python\Python37\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     132                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#     136         return positional_wrapper
#
# ~\AppData\Roaming\Python\Python37\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     913             callback(resp)
#     914         if resp.status >= 300:
# --> 915             raise HttpError(resp, content, uri=self.uri)
#     916         return self.postproc(resp, content)
#     917
#
# HttpError: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?cx=d4d8d063ff32c6dc7&q=red+velvet+cupcake&searchType=image&num=1&start=1&imgType=photo&imgSize=MEDIUM&fileType=jpg&safe=high&rights=cc_publicdomain&key=AIzaSyDruwecqgBsd0T9DjUWnQeR88WwrM3d9cI&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:498952883267'.". Details: "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:498952883267'.">

# %%
# this will only search for images:
gis.search(search_params=_search_params) 
    
# this will search, download and resize:
gis.search(search_params=_search_params, path_to_dir='/path/', width=500, height=500)

# search first, then download and resize afterwards:
gis.search(search_params=_search_params)
for image in gis.results():
    image.download('/path/')
    image.resize(500, 500)
